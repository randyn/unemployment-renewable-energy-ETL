# %%
import pandas as pd
import requests
from config import energy_api_key
from pprint import pprint
import numpy as np

# %%
fuel_types_url = f"http://api.eia.gov/category/?api_key={energy_api_key}&category_id=3"

# %%
response = requests.get(fuel_types_url)

# %%
energy_category_objects = response.json()['category']['childcategories']
energy_category_objects
# Out:
# [{'category_id': 4, 'name': 'Coal'},
#  {'category_id': 7, 'name': 'Petroleum liquids'},
#  {'category_id': 8, 'name': 'Petroleum coke'},
#  {'category_id': 9, 'name': 'Natural gas'},
#  {'category_id': 10, 'name': 'Other gases'},
#  {'category_id': 11, 'name': 'Nuclear'},
#  {'category_id': 12, 'name': 'Conventional hydroelectric'},
#  {'category_id': 13, 'name': 'Other renewables (total)'},
#  {'category_id': 14, 'name': 'Wind'},
#  {'category_id': 15, 'name': 'All utility-scale solar'},
#  {'category_id': 16, 'name': 'Wood and wood-derived fuels'},
#  {'category_id': 17, 'name': 'Geothermal'},
#  {'category_id': 18, 'name': 'Other biomass'},
#  {'category_id': 19, 'name': 'Hydro-electric pumped storage'},
#  {'category_id': 20, 'name': 'Other'},
#  {'category_id': 1718400, 'name': 'Utility-scale photovoltaic'},
#  {'category_id': 1718401, 'name': 'Utility-scale thermal'},
#  {'category_id': 1718408, 'name': 'All solar'},
#  {'category_id': 1718409, 'name': 'Small-scale solar photovoltaic'},
#  {'category_id': 1736519, 'name': 'All fuels'}]

# %%
renewable_energies = ['Conventional hydroelectric',\
                      'Other renewables (total)',\
                      'Wind',\
                      'Wood and wood-derived fuels'\
                      'Other biomass',\
                      'All solar',\
                      'Geothermal',\
                      'Utility-scale thermal',\
                      'Other renewables (total)'\
                     ]

# %%
carbon_neutral = renewable_energies + ['Nuclear']
carbon_neutral
# Out:
# ['Conventional hydroelectric',
#  'Other renewables (total)',
#  'Wind',
#  'Wood and wood-derived fuelsOther biomass',
#  'All solar',
#  'Geothermal',
#  'Utility-scale thermal',
#  'Other renewables (total)',
#  'Nuclear']

# %%
def seriesIDGenerator():
    return 'ELEC.GEN.WND-AK-99.M'

# %%
wind_data_url = f"http://api.eia.gov/category/?api_key={energy_api_key}&category_id=14"
wind_child_series_data = requests.get(wind_data_url).json()['category']['childseries']
pprint(wind_child_series_data)
# Out:
# [{'f': 'A',
#   'name': 'Net generation : wind : Alaska : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-AK-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Alaska : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-AK-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Alaska : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-AK-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Arizona : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-AZ-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Arizona : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-AZ-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Arizona : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-AZ-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : California : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-CA-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : California : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : California : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-CA-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Colorado : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-CO-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Colorado : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CO-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Colorado : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-CO-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Connecticut : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-CT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Connecticut : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Connecticut : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-CT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Delaware : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-DE-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Delaware : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-DE-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Delaware : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-DE-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : East North Central (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-ENC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : East North Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-ENC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : East North Central (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-ENC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : East South Central (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-ESC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : East South Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-ESC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : East South Central (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-ESC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Hawaii : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-HI-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Hawaii : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-HI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Hawaii : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-HI-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Iowa : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-IA-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Iowa : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Iowa : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-IA-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Idaho : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-ID-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Idaho : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ID-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Idaho : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-ID-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Illinois : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-IL-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Illinois : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IL-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Illinois : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-IL-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Indiana : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-IN-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Indiana : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Indiana : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-IN-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Kansas : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-KS-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Kansas : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-KS-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Kansas : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-KS-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Massachusetts : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MA-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Massachusetts : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Massachusetts : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MA-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Middle Atlantic (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-MAT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Middle Atlantic (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-MAT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Middle Atlantic (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-MAT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Maryland : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MD-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Maryland : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MD-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Maryland : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MD-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Maine : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-ME-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Maine : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ME-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Maine : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-ME-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Michigan : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MI-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Michigan : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Michigan : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MI-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Minnesota : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MN-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Minnesota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Minnesota : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MN-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Missouri : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MO-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Missouri : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MO-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Missouri : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MO-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Montana : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Montana : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Montana : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Mountain (total) : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-MTN-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Mountain (total) : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MTN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Mountain (total) : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-MTN-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : North Carolina : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : North Carolina : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : North Carolina : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : North Dakota : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-ND-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : North Dakota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ND-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : North Dakota : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-ND-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Nebraska : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NE-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Nebraska : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NE-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Nebraska : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NE-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : New England (total) : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NEW-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New England (total) : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NEW-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : New England (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-NEW-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : New Hampshire : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NH-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Hampshire : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NH-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : New Hampshire : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NH-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : New Jersey : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NJ-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Jersey : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NJ-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : New Jersey : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NJ-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : New Mexico : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NM-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Mexico : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NM-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : New Mexico : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NM-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Nevada : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NV-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Nevada : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NV-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Nevada : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NV-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : New York : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-NY-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New York : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NY-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : New York : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-NY-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Ohio : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-OH-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Ohio : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OH-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Ohio : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-OH-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Oklahoma : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-OK-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Oklahoma : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OK-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Oklahoma : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-OK-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Oregon : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-OR-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Oregon : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OR-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Oregon : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-OR-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Pennsylvania : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-PA-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pennsylvania : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-PA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Pennsylvania : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-PA-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Pacific Contiguous (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-PCC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pacific Contiguous (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-PCC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Pacific Contiguous (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-PCC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Pacific Noncontiguous (total) : all sectors '
#           ': annual',
#   'series_id': 'ELEC.GEN.WND-PCN-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pacific Noncontiguous (total) : all sectors '
#           ': monthly',
#   'series_id': 'ELEC.GEN.WND-PCN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Pacific Noncontiguous (total) : all sectors '
#           ': quarterly',
#   'series_id': 'ELEC.GEN.WND-PCN-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Rhode Island : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-RI-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Rhode Island : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-RI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Rhode Island : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-RI-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : South Atlantic (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-SAT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : South Atlantic (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-SAT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : South Atlantic (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-SAT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : South Dakota : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-SD-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : South Dakota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-SD-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : South Dakota : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-SD-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Tennessee : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-TN-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Tennessee : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-TN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Tennessee : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-TN-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Texas : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-TX-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Texas : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-TX-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Texas : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-TX-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : United States : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-US-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : United States : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-US-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : United States : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-US-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Utah : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-UT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Utah : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-UT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Utah : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-UT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Vermont : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-VT-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Vermont : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-VT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Vermont : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-VT-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Washington : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-WA-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Washington : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Washington : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-WA-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Wisconsin : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-WI-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Wisconsin : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Wisconsin : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-WI-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : West North Central (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-WNC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West North Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-WNC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : West North Central (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-WNC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : West South Central (total) : all sectors : '
#           'annual',
#   'series_id': 'ELEC.GEN.WND-WSC-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West South Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-WSC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : West South Central (total) : all sectors : '
#           'quarterly',
#   'series_id': 'ELEC.GEN.WND-WSC-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : West Virginia : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-WV-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West Virginia : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WV-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : West Virginia : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-WV-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'A',
#   'name': 'Net generation : wind : Wyoming : all sectors : annual',
#   'series_id': 'ELEC.GEN.WND-WY-99.A',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Wyoming : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WY-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'Q',
#   'name': 'Net generation : wind : Wyoming : all sectors : quarterly',
#   'series_id': 'ELEC.GEN.WND-WY-99.Q',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'}]

# %%
monthly_wind_generation_series = [wind_child_series \
                                  for wind_child_series in wind_child_series_data \
                                  if wind_child_series['f'] == 'M'\
                                 ]
pprint(monthly_wind_generation_series)
# Out:
# [{'f': 'M',
#   'name': 'Net generation : wind : Alaska : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-AK-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Arizona : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-AZ-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : California : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Colorado : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CO-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Connecticut : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-CT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Delaware : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-DE-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : East North Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-ENC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : East South Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-ESC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Hawaii : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-HI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Iowa : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Idaho : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ID-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Illinois : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IL-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Indiana : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-IN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Kansas : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-KS-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Massachusetts : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Middle Atlantic (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-MAT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Maryland : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MD-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Maine : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ME-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Michigan : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Minnesota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Missouri : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MO-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Montana : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Mountain (total) : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-MTN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : North Carolina : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : North Dakota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-ND-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Nebraska : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NE-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New England (total) : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NEW-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Hampshire : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NH-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Jersey : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NJ-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New Mexico : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NM-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Nevada : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NV-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : New York : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-NY-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Ohio : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OH-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Oklahoma : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OK-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Oregon : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-OR-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pennsylvania : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-PA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pacific Contiguous (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-PCC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Pacific Noncontiguous (total) : all sectors '
#           ': monthly',
#   'series_id': 'ELEC.GEN.WND-PCN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Rhode Island : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-RI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : South Atlantic (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-SAT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : South Dakota : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-SD-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Tennessee : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-TN-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Texas : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-TX-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : United States : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-US-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Utah : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-UT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Vermont : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-VT-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Washington : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WA-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Wisconsin : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WI-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West North Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-WNC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West South Central (total) : all sectors : '
#           'monthly',
#   'series_id': 'ELEC.GEN.WND-WSC-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : West Virginia : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WV-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'},
#  {'f': 'M',
#   'name': 'Net generation : wind : Wyoming : all sectors : monthly',
#   'series_id': 'ELEC.GEN.WND-WY-99.M',
#   'units': 'thousand megawatthours',
#   'updated': '01-MAR-19 12.40.06 AM'}]

# %%
def regionFromSeriesName(series_name):
    return series_name.split(' : ')[2]

# %%
region_to_monthly_wind_urls = {regionFromSeriesName(monthly_wind_series['name']): monthly_wind_series['series_id']\
 for monthly_wind_series in monthly_wind_generation_series\
}
region_to_monthly_wind_urls
# Out:
# {'Alaska': 'ELEC.GEN.WND-AK-99.M',
#  'Arizona': 'ELEC.GEN.WND-AZ-99.M',
#  'California': 'ELEC.GEN.WND-CA-99.M',
#  'Colorado': 'ELEC.GEN.WND-CO-99.M',
#  'Connecticut': 'ELEC.GEN.WND-CT-99.M',
#  'Delaware': 'ELEC.GEN.WND-DE-99.M',
#  'East North Central (total)': 'ELEC.GEN.WND-ENC-99.M',
#  'East South Central (total)': 'ELEC.GEN.WND-ESC-99.M',
#  'Hawaii': 'ELEC.GEN.WND-HI-99.M',
#  'Iowa': 'ELEC.GEN.WND-IA-99.M',
#  'Idaho': 'ELEC.GEN.WND-ID-99.M',
#  'Illinois': 'ELEC.GEN.WND-IL-99.M',
#  'Indiana': 'ELEC.GEN.WND-IN-99.M',
#  'Kansas': 'ELEC.GEN.WND-KS-99.M',
#  'Massachusetts': 'ELEC.GEN.WND-MA-99.M',
#  'Middle Atlantic (total)': 'ELEC.GEN.WND-MAT-99.M',
#  'Maryland': 'ELEC.GEN.WND-MD-99.M',
#  'Maine': 'ELEC.GEN.WND-ME-99.M',
#  'Michigan': 'ELEC.GEN.WND-MI-99.M',
#  'Minnesota': 'ELEC.GEN.WND-MN-99.M',
#  'Missouri': 'ELEC.GEN.WND-MO-99.M',
#  'Montana': 'ELEC.GEN.WND-MT-99.M',
#  'Mountain (total)': 'ELEC.GEN.WND-MTN-99.M',
#  'North Carolina': 'ELEC.GEN.WND-NC-99.M',
#  'North Dakota': 'ELEC.GEN.WND-ND-99.M',
#  'Nebraska': 'ELEC.GEN.WND-NE-99.M',
#  'New England (total)': 'ELEC.GEN.WND-NEW-99.M',
#  'New Hampshire': 'ELEC.GEN.WND-NH-99.M',
#  'New Jersey': 'ELEC.GEN.WND-NJ-99.M',
#  'New Mexico': 'ELEC.GEN.WND-NM-99.M',
#  'Nevada': 'ELEC.GEN.WND-NV-99.M',
#  'New York': 'ELEC.GEN.WND-NY-99.M',
#  'Ohio': 'ELEC.GEN.WND-OH-99.M',
#  'Oklahoma': 'ELEC.GEN.WND-OK-99.M',
#  'Oregon': 'ELEC.GEN.WND-OR-99.M',
#  'Pennsylvania': 'ELEC.GEN.WND-PA-99.M',
#  'Pacific Contiguous (total)': 'ELEC.GEN.WND-PCC-99.M',
#  'Pacific Noncontiguous (total)': 'ELEC.GEN.WND-PCN-99.M',
#  'Rhode Island': 'ELEC.GEN.WND-RI-99.M',
#  'South Atlantic (total)': 'ELEC.GEN.WND-SAT-99.M',
#  'South Dakota': 'ELEC.GEN.WND-SD-99.M',
#  'Tennessee': 'ELEC.GEN.WND-TN-99.M',
#  'Texas': 'ELEC.GEN.WND-TX-99.M',
#  'United States': 'ELEC.GEN.WND-US-99.M',
#  'Utah': 'ELEC.GEN.WND-UT-99.M',
#  'Vermont': 'ELEC.GEN.WND-VT-99.M',
#  'Washington': 'ELEC.GEN.WND-WA-99.M',
#  'Wisconsin': 'ELEC.GEN.WND-WI-99.M',
#  'West North Central (total)': 'ELEC.GEN.WND-WNC-99.M',
#  'West South Central (total)': 'ELEC.GEN.WND-WSC-99.M',
#  'West Virginia': 'ELEC.GEN.WND-WV-99.M',
#  'Wyoming': 'ELEC.GEN.WND-WY-99.M'}

# %%
def getSeriesData(series_id):
    url = f"http://api.eia.gov/series/?api_key={energy_api_key}&series_id={series_id}"
    response = requests.get(alaska_wind_series_url)
    return response.json()['series'][0]['data']

# %%
wind_region_series_data = [ [region, getSeriesData(series_id)] \
 for (region, series_id) in region_to_monthly_wind_urls.items()]
wind_region_series_data[0]
# Out:
# ['Alaska',
#  [['201812', 11.84345],
#   ['201811', 11.98104],
#   ['201810', 10.25316],
#   ['201809', 9.39741],
#   ['201808', None],
#   ['201807', None],
#   ['201806', None],
#   ['201805', 12.1464],
#   ['201804', 14.31442],
#   ['201803', 14.75622],
#   ['201802', 15.2678],
#   ['201801', 14.51298],
#   ['201712', 13.49192],
#   ['201711', 13.26932],
#   ['201710', 14.00132],
#   ['201709', 10.11247],
#   ['201708', 7.35166],
#   ['201707', 9.00838],
#   ['201706', 10.9124],
#   ['201705', 12.5076],
#   ['201704', 13.97538],
#   ['201703', 14.08744],
#   ['201702', 11.75448],
#   ['201701', 11.21466],
#   ['201612', 10.84137],
#   ['201611', 17.4438],
#   ['201610', 19.45514],
#   ['201609', 16.07405],
#   ['201608', 18.20985],
#   ['201607', 16.20603],
#   ['201606', 18.15497],
#   ['201605', 13.26432],
#   ['201604', 18.07526],
#   ['201603', 9.33311],
#   ['201602', 7.99766],
#   ['201601', 4.24547],
#   ['201512', 16.23006],
#   ['201511', 18.43651],
#   ['201510', 10.48074],
#   ['201509', 14.32482],
#   ['201508', 11.6432],
#   ['201507', 13.32097],
#   ['201506', 13.09057],
#   ['201505', 17.08183],
#   ['201504', 19.18777],
#   ['201503', 11.07535],
#   ['201502', 9.88483],
#   ['201501', 4.93735],
#   ['201412', 11.537],
#   ['201411', 12.90254],
#   ['201410', 13.70742],
#   ['201409', 9.0683],
#   ['201408', 15.70777],
#   ['201407', 19.35414],
#   ['201406', 18.70647],
#   ['201405', 9.11345],
#   ['201404', 19.03014],
#   ['201403', 11.35078],
#   ['201402', 4.23899],
#   ['201401', 7.24],
#   ['201312', 9.86624],
#   ['201311', 10.10642],
#   ['201310', 9.65963],
#   ['201309', 15.06117],
#   ['201308', 17.44717],
#   ['201307', 15.40162],
#   ['201306', 18.67837],
#   ['201305', 9.86422],
#   ['201304', 7.16001],
#   ['201303', 7.46205],
#   ['201302', 16.50547],
#   ['201301', 8.07664],
#   ['201212', 6.55997],
#   ['201211', None],
#   ['201210', None],
#   ['201209', 4.48528],
#   ['201208', 1.90699],
#   ['201207', 2.79567],
#   ['201206', 1.67562],
#   ['201205', 2.16885],
#   ['201204', 2.00854],
#   ['201203', 2.04053],
#   ['201202', 1.44879],
#   ['201201', None],
#   ['201112', 1.62115],
#   ['201111', 1.68208],
#   ['201110', 1.15438],
#   ['201109', 0.7534],
#   ['201108', 1.42933],
#   ['201107', 1.29988],
#   ['201106', 1.09003],
#   ['201105', 0.93613],
#   ['201104', 0.43814],
#   ['201103', 1.56418],
#   ['201102', 0.05916],
#   ['201101', 0.41813],
#   ['201012', 0.36093],
#   ['201011', 0.71944],
#   ['201010', 1.13217],
#   ['201009', 1.17705],
#   ['201008', 1.76385],
#   ['201007', 1.37293],
#   ['201006', 1.25046],
#   ['201005', 0.99963],
#   ['201004', 1.36203],
#   ['201003', 1.36758],
#   ['201002', 0.68505],
#   ['201001', 0.41588],
#   ['200912', 0.30953],
#   ['200911', 1.22224],
#   ['200910', 0.5067],
#   ['200909', 1.21284],
#   ['200908', 1.28276],
#   ['200907', 1.32511],
#   ['200906', 0.87538],
#   ['200905', 0.00283],
#   ['200904', 0.069],
#   ['200903', 0.08362],
#   ['200902', 0.08875],
#   ['200901', 0.04826],
#   ['200812', 0.00327],
#   ['200811', 0.00467],
#   ['200810', 0.00536],
#   ['200809', 0.00493],
#   ['200808', 0.00839],
#   ['200807', 0.00717],
#   ['200806', 0.00624],
#   ['200805', 0.00591],
#   ['200804', 0.00536],
#   ['200803', 0.00471],
#   ['200802', 0.00334],
#   ['200801', 0.00864],
#   ['200712', 0.11317],
#   ['200711', 0.05208],
#   ['200710', 0.12629],
#   ['200709', 0.10029],
#   ['200708', 0.0955],
#   ['200707', 0.12725],
#   ['200706', 0.08737],
#   ['200705', 0.06506],
#   ['200704', 0.08433],
#   ['200703', 0.04894],
#   ['200702', 0.05536],
#   ['200701', 0.05639],
#   ['200612', 0.08516],
#   ['200611', 0.07921],
#   ['200610', 0.07014],
#   ['200609', 0.04942],
#   ['200608', 0.04047],
#   ['200607', 0.04676],
#   ['200606', 0.04585],
#   ['200605', 0.06834],
#   ['200604', 0.07261],
#   ['200603', 0.07225],
#   ['200602', 0.07075],
#   ['200601', 0.08703],
#   ['200512', 0.07937],
#   ['200511', 0.09749],
#   ['200510', 0.07092],
#   ['200509', 0.0535],
#   ['200508', 0.02536],
#   ['200507', 0.02818],
#   ['200506', 0.04122],
#   ['200505', 0.04858],
#   ['200504', 0.04573],
#   ['200503', 0.04518],
#   ['200502', 0.0304],
#   ['200501', 0.02308],
#   ['200312', 0],
#   ['200311', 0],
#   ['200310', 0],
#   ['200309', 0],
#   ['200308', 0],
#   ['200307', 0],
#   ['200306', 0],
#   ['200305', 0],
#   ['200304', 0],
#   ['200303', 0],
#   ['200302', 0],
#   ['200301', 0],
#   ['200112', 0.097],
#   ['200111', 0.086],
#   ['200110', 0.083],
#   ['200109', 0.086],
#   ['200108', 0.073],
#   ['200107', 0.074],
#   ['200106', 0.07],
#   ['200105', 0.069],
#   ['200104', 0.071],
#   ['200103', 0.081],
#   ['200102', 0.074],
#   ['200101', 0.087]]]

# %%
def formatedSeriesData(region, fuel_type, series_data):
    return [{"region": region, \
             "date": date, \
             "energy_production": energy, \
             "fuel_type": fuel_type
            } \
            for [date, energy] \
            in series_data
           ]

# %%
formatted_wind_region_series_data = [formatedSeriesData(region, "wind", series_data) \
                                     for [region, series_data] in wind_region_series_data]
formatted_wind_region_series_data[:5]
# Out:
# [[{'region': 'Alaska',
#    'date': '201812',
#    'energy_production': 11.84345,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201811',
#    'energy_production': 11.98104,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201810',
#    'energy_production': 10.25316,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201809',
#    'energy_production': 9.39741,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201808',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201807',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201806',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201805',
#    'energy_production': 12.1464,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201804',
#    'energy_production': 14.31442,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201803',
#    'energy_production': 14.75622,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201802',
#    'energy_production': 15.2678,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201801',
#    'energy_production': 14.51298,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201712',
#    'energy_production': 13.49192,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201711',
#    'energy_production': 13.26932,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201710',
#    'energy_production': 14.00132,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201709',
#    'energy_production': 10.11247,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201708',
#    'energy_production': 7.35166,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201707',
#    'energy_production': 9.00838,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201706',
#    'energy_production': 10.9124,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201705',
#    'energy_production': 12.5076,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201704',
#    'energy_production': 13.97538,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201703',
#    'energy_production': 14.08744,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201702',
#    'energy_production': 11.75448,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201701',
#    'energy_production': 11.21466,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201612',
#    'energy_production': 10.84137,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201611',
#    'energy_production': 17.4438,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201610',
#    'energy_production': 19.45514,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201609',
#    'energy_production': 16.07405,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201608',
#    'energy_production': 18.20985,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201607',
#    'energy_production': 16.20603,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201606',
#    'energy_production': 18.15497,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201605',
#    'energy_production': 13.26432,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201604',
#    'energy_production': 18.07526,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201603',
#    'energy_production': 9.33311,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201602',
#    'energy_production': 7.99766,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201601',
#    'energy_production': 4.24547,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201512',
#    'energy_production': 16.23006,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201511',
#    'energy_production': 18.43651,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201510',
#    'energy_production': 10.48074,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201509',
#    'energy_production': 14.32482,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201508',
#    'energy_production': 11.6432,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201507',
#    'energy_production': 13.32097,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201506',
#    'energy_production': 13.09057,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201505',
#    'energy_production': 17.08183,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201504',
#    'energy_production': 19.18777,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201503',
#    'energy_production': 11.07535,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201502',
#    'energy_production': 9.88483,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201501',
#    'energy_production': 4.93735,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201412',
#    'energy_production': 11.537,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201411',
#    'energy_production': 12.90254,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201410',
#    'energy_production': 13.70742,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201409',
#    'energy_production': 9.0683,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201408',
#    'energy_production': 15.70777,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201407',
#    'energy_production': 19.35414,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201406',
#    'energy_production': 18.70647,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201405',
#    'energy_production': 9.11345,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201404',
#    'energy_production': 19.03014,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201403',
#    'energy_production': 11.35078,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201402',
#    'energy_production': 4.23899,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201401',
#    'energy_production': 7.24,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201312',
#    'energy_production': 9.86624,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201311',
#    'energy_production': 10.10642,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201310',
#    'energy_production': 9.65963,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201309',
#    'energy_production': 15.06117,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201308',
#    'energy_production': 17.44717,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201307',
#    'energy_production': 15.40162,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201306',
#    'energy_production': 18.67837,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201305',
#    'energy_production': 9.86422,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201304',
#    'energy_production': 7.16001,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201303',
#    'energy_production': 7.46205,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201302',
#    'energy_production': 16.50547,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201301',
#    'energy_production': 8.07664,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201212',
#    'energy_production': 6.55997,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201211',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201210',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201209',
#    'energy_production': 4.48528,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201208',
#    'energy_production': 1.90699,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201207',
#    'energy_production': 2.79567,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201206',
#    'energy_production': 1.67562,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201205',
#    'energy_production': 2.16885,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201204',
#    'energy_production': 2.00854,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201203',
#    'energy_production': 2.04053,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201202',
#    'energy_production': 1.44879,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201201',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201112',
#    'energy_production': 1.62115,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201111',
#    'energy_production': 1.68208,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201110',
#    'energy_production': 1.15438,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201109',
#    'energy_production': 0.7534,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201108',
#    'energy_production': 1.42933,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201107',
#    'energy_production': 1.29988,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201106',
#    'energy_production': 1.09003,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201105',
#    'energy_production': 0.93613,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201104',
#    'energy_production': 0.43814,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201103',
#    'energy_production': 1.56418,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201102',
#    'energy_production': 0.05916,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201101',
#    'energy_production': 0.41813,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201012',
#    'energy_production': 0.36093,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201011',
#    'energy_production': 0.71944,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201010',
#    'energy_production': 1.13217,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201009',
#    'energy_production': 1.17705,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201008',
#    'energy_production': 1.76385,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201007',
#    'energy_production': 1.37293,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201006',
#    'energy_production': 1.25046,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201005',
#    'energy_production': 0.99963,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201004',
#    'energy_production': 1.36203,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201003',
#    'energy_production': 1.36758,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201002',
#    'energy_production': 0.68505,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '201001',
#    'energy_production': 0.41588,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200912',
#    'energy_production': 0.30953,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200911',
#    'energy_production': 1.22224,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200910',
#    'energy_production': 0.5067,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200909',
#    'energy_production': 1.21284,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200908',
#    'energy_production': 1.28276,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200907',
#    'energy_production': 1.32511,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200906',
#    'energy_production': 0.87538,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200905',
#    'energy_production': 0.00283,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200904',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200903',
#    'energy_production': 0.08362,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200902',
#    'energy_production': 0.08875,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200901',
#    'energy_production': 0.04826,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200812',
#    'energy_production': 0.00327,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200811',
#    'energy_production': 0.00467,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200810',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200809',
#    'energy_production': 0.00493,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200808',
#    'energy_production': 0.00839,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200807',
#    'energy_production': 0.00717,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200806',
#    'energy_production': 0.00624,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200805',
#    'energy_production': 0.00591,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200804',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200803',
#    'energy_production': 0.00471,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200802',
#    'energy_production': 0.00334,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200801',
#    'energy_production': 0.00864,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200712',
#    'energy_production': 0.11317,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200711',
#    'energy_production': 0.05208,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200710',
#    'energy_production': 0.12629,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200709',
#    'energy_production': 0.10029,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200708',
#    'energy_production': 0.0955,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200707',
#    'energy_production': 0.12725,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200706',
#    'energy_production': 0.08737,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200705',
#    'energy_production': 0.06506,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200704',
#    'energy_production': 0.08433,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200703',
#    'energy_production': 0.04894,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200702',
#    'energy_production': 0.05536,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200701',
#    'energy_production': 0.05639,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200612',
#    'energy_production': 0.08516,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200611',
#    'energy_production': 0.07921,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200610',
#    'energy_production': 0.07014,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200609',
#    'energy_production': 0.04942,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200608',
#    'energy_production': 0.04047,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200607',
#    'energy_production': 0.04676,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200606',
#    'energy_production': 0.04585,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200605',
#    'energy_production': 0.06834,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200604',
#    'energy_production': 0.07261,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200603',
#    'energy_production': 0.07225,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200602',
#    'energy_production': 0.07075,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200601',
#    'energy_production': 0.08703,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200512',
#    'energy_production': 0.07937,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200511',
#    'energy_production': 0.09749,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200510',
#    'energy_production': 0.07092,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200509',
#    'energy_production': 0.0535,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200508',
#    'energy_production': 0.02536,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200507',
#    'energy_production': 0.02818,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200506',
#    'energy_production': 0.04122,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200505',
#    'energy_production': 0.04858,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200504',
#    'energy_production': 0.04573,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200503',
#    'energy_production': 0.04518,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200502',
#    'energy_production': 0.0304,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200501',
#    'energy_production': 0.02308,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200312',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200311',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200310',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200309',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200308',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200307',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200306',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200305',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200304',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200303',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200302',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200301',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200112',
#    'energy_production': 0.097,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200111',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200110',
#    'energy_production': 0.083,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200109',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200108',
#    'energy_production': 0.073,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200107',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200106',
#    'energy_production': 0.07,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200105',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200104',
#    'energy_production': 0.071,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200103',
#    'energy_production': 0.081,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200102',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Alaska',
#    'date': '200101',
#    'energy_production': 0.087,
#    'fuel_type': 'wind'}],
#  [{'region': 'Arizona',
#    'date': '201812',
#    'energy_production': 11.84345,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201811',
#    'energy_production': 11.98104,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201810',
#    'energy_production': 10.25316,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201809',
#    'energy_production': 9.39741,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201808',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201807',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201806',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201805',
#    'energy_production': 12.1464,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201804',
#    'energy_production': 14.31442,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201803',
#    'energy_production': 14.75622,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201802',
#    'energy_production': 15.2678,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201801',
#    'energy_production': 14.51298,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201712',
#    'energy_production': 13.49192,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201711',
#    'energy_production': 13.26932,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201710',
#    'energy_production': 14.00132,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201709',
#    'energy_production': 10.11247,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201708',
#    'energy_production': 7.35166,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201707',
#    'energy_production': 9.00838,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201706',
#    'energy_production': 10.9124,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201705',
#    'energy_production': 12.5076,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201704',
#    'energy_production': 13.97538,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201703',
#    'energy_production': 14.08744,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201702',
#    'energy_production': 11.75448,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201701',
#    'energy_production': 11.21466,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201612',
#    'energy_production': 10.84137,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201611',
#    'energy_production': 17.4438,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201610',
#    'energy_production': 19.45514,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201609',
#    'energy_production': 16.07405,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201608',
#    'energy_production': 18.20985,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201607',
#    'energy_production': 16.20603,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201606',
#    'energy_production': 18.15497,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201605',
#    'energy_production': 13.26432,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201604',
#    'energy_production': 18.07526,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201603',
#    'energy_production': 9.33311,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201602',
#    'energy_production': 7.99766,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201601',
#    'energy_production': 4.24547,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201512',
#    'energy_production': 16.23006,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201511',
#    'energy_production': 18.43651,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201510',
#    'energy_production': 10.48074,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201509',
#    'energy_production': 14.32482,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201508',
#    'energy_production': 11.6432,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201507',
#    'energy_production': 13.32097,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201506',
#    'energy_production': 13.09057,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201505',
#    'energy_production': 17.08183,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201504',
#    'energy_production': 19.18777,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201503',
#    'energy_production': 11.07535,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201502',
#    'energy_production': 9.88483,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201501',
#    'energy_production': 4.93735,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201412',
#    'energy_production': 11.537,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201411',
#    'energy_production': 12.90254,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201410',
#    'energy_production': 13.70742,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201409',
#    'energy_production': 9.0683,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201408',
#    'energy_production': 15.70777,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201407',
#    'energy_production': 19.35414,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201406',
#    'energy_production': 18.70647,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201405',
#    'energy_production': 9.11345,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201404',
#    'energy_production': 19.03014,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201403',
#    'energy_production': 11.35078,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201402',
#    'energy_production': 4.23899,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201401',
#    'energy_production': 7.24,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201312',
#    'energy_production': 9.86624,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201311',
#    'energy_production': 10.10642,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201310',
#    'energy_production': 9.65963,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201309',
#    'energy_production': 15.06117,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201308',
#    'energy_production': 17.44717,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201307',
#    'energy_production': 15.40162,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201306',
#    'energy_production': 18.67837,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201305',
#    'energy_production': 9.86422,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201304',
#    'energy_production': 7.16001,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201303',
#    'energy_production': 7.46205,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201302',
#    'energy_production': 16.50547,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201301',
#    'energy_production': 8.07664,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201212',
#    'energy_production': 6.55997,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201211',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201210',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201209',
#    'energy_production': 4.48528,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201208',
#    'energy_production': 1.90699,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201207',
#    'energy_production': 2.79567,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201206',
#    'energy_production': 1.67562,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201205',
#    'energy_production': 2.16885,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201204',
#    'energy_production': 2.00854,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201203',
#    'energy_production': 2.04053,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201202',
#    'energy_production': 1.44879,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201201',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201112',
#    'energy_production': 1.62115,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201111',
#    'energy_production': 1.68208,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201110',
#    'energy_production': 1.15438,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201109',
#    'energy_production': 0.7534,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201108',
#    'energy_production': 1.42933,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201107',
#    'energy_production': 1.29988,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201106',
#    'energy_production': 1.09003,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201105',
#    'energy_production': 0.93613,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201104',
#    'energy_production': 0.43814,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201103',
#    'energy_production': 1.56418,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201102',
#    'energy_production': 0.05916,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201101',
#    'energy_production': 0.41813,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201012',
#    'energy_production': 0.36093,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201011',
#    'energy_production': 0.71944,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201010',
#    'energy_production': 1.13217,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201009',
#    'energy_production': 1.17705,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201008',
#    'energy_production': 1.76385,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201007',
#    'energy_production': 1.37293,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201006',
#    'energy_production': 1.25046,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201005',
#    'energy_production': 0.99963,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201004',
#    'energy_production': 1.36203,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201003',
#    'energy_production': 1.36758,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201002',
#    'energy_production': 0.68505,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '201001',
#    'energy_production': 0.41588,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200912',
#    'energy_production': 0.30953,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200911',
#    'energy_production': 1.22224,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200910',
#    'energy_production': 0.5067,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200909',
#    'energy_production': 1.21284,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200908',
#    'energy_production': 1.28276,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200907',
#    'energy_production': 1.32511,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200906',
#    'energy_production': 0.87538,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200905',
#    'energy_production': 0.00283,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200904',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200903',
#    'energy_production': 0.08362,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200902',
#    'energy_production': 0.08875,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200901',
#    'energy_production': 0.04826,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200812',
#    'energy_production': 0.00327,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200811',
#    'energy_production': 0.00467,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200810',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200809',
#    'energy_production': 0.00493,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200808',
#    'energy_production': 0.00839,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200807',
#    'energy_production': 0.00717,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200806',
#    'energy_production': 0.00624,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200805',
#    'energy_production': 0.00591,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200804',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200803',
#    'energy_production': 0.00471,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200802',
#    'energy_production': 0.00334,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200801',
#    'energy_production': 0.00864,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200712',
#    'energy_production': 0.11317,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200711',
#    'energy_production': 0.05208,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200710',
#    'energy_production': 0.12629,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200709',
#    'energy_production': 0.10029,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200708',
#    'energy_production': 0.0955,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200707',
#    'energy_production': 0.12725,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200706',
#    'energy_production': 0.08737,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200705',
#    'energy_production': 0.06506,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200704',
#    'energy_production': 0.08433,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200703',
#    'energy_production': 0.04894,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200702',
#    'energy_production': 0.05536,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200701',
#    'energy_production': 0.05639,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200612',
#    'energy_production': 0.08516,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200611',
#    'energy_production': 0.07921,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200610',
#    'energy_production': 0.07014,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200609',
#    'energy_production': 0.04942,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200608',
#    'energy_production': 0.04047,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200607',
#    'energy_production': 0.04676,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200606',
#    'energy_production': 0.04585,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200605',
#    'energy_production': 0.06834,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200604',
#    'energy_production': 0.07261,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200603',
#    'energy_production': 0.07225,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200602',
#    'energy_production': 0.07075,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200601',
#    'energy_production': 0.08703,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200512',
#    'energy_production': 0.07937,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200511',
#    'energy_production': 0.09749,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200510',
#    'energy_production': 0.07092,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200509',
#    'energy_production': 0.0535,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200508',
#    'energy_production': 0.02536,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200507',
#    'energy_production': 0.02818,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200506',
#    'energy_production': 0.04122,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200505',
#    'energy_production': 0.04858,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200504',
#    'energy_production': 0.04573,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200503',
#    'energy_production': 0.04518,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200502',
#    'energy_production': 0.0304,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200501',
#    'energy_production': 0.02308,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200312',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200311',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200310',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200309',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200308',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200307',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200306',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200305',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200304',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200303',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200302',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200301',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200112',
#    'energy_production': 0.097,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200111',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200110',
#    'energy_production': 0.083,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200109',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200108',
#    'energy_production': 0.073,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200107',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200106',
#    'energy_production': 0.07,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200105',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200104',
#    'energy_production': 0.071,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200103',
#    'energy_production': 0.081,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200102',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Arizona',
#    'date': '200101',
#    'energy_production': 0.087,
#    'fuel_type': 'wind'}],
#  [{'region': 'California',
#    'date': '201812',
#    'energy_production': 11.84345,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201811',
#    'energy_production': 11.98104,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201810',
#    'energy_production': 10.25316,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201809',
#    'energy_production': 9.39741,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201808',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201807',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201806',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201805',
#    'energy_production': 12.1464,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201804',
#    'energy_production': 14.31442,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201803',
#    'energy_production': 14.75622,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201802',
#    'energy_production': 15.2678,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201801',
#    'energy_production': 14.51298,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201712',
#    'energy_production': 13.49192,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201711',
#    'energy_production': 13.26932,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201710',
#    'energy_production': 14.00132,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201709',
#    'energy_production': 10.11247,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201708',
#    'energy_production': 7.35166,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201707',
#    'energy_production': 9.00838,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201706',
#    'energy_production': 10.9124,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201705',
#    'energy_production': 12.5076,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201704',
#    'energy_production': 13.97538,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201703',
#    'energy_production': 14.08744,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201702',
#    'energy_production': 11.75448,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201701',
#    'energy_production': 11.21466,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201612',
#    'energy_production': 10.84137,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201611',
#    'energy_production': 17.4438,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201610',
#    'energy_production': 19.45514,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201609',
#    'energy_production': 16.07405,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201608',
#    'energy_production': 18.20985,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201607',
#    'energy_production': 16.20603,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201606',
#    'energy_production': 18.15497,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201605',
#    'energy_production': 13.26432,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201604',
#    'energy_production': 18.07526,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201603',
#    'energy_production': 9.33311,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201602',
#    'energy_production': 7.99766,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201601',
#    'energy_production': 4.24547,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201512',
#    'energy_production': 16.23006,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201511',
#    'energy_production': 18.43651,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201510',
#    'energy_production': 10.48074,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201509',
#    'energy_production': 14.32482,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201508',
#    'energy_production': 11.6432,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201507',
#    'energy_production': 13.32097,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201506',
#    'energy_production': 13.09057,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201505',
#    'energy_production': 17.08183,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201504',
#    'energy_production': 19.18777,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201503',
#    'energy_production': 11.07535,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201502',
#    'energy_production': 9.88483,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201501',
#    'energy_production': 4.93735,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201412',
#    'energy_production': 11.537,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201411',
#    'energy_production': 12.90254,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201410',
#    'energy_production': 13.70742,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201409',
#    'energy_production': 9.0683,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201408',
#    'energy_production': 15.70777,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201407',
#    'energy_production': 19.35414,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201406',
#    'energy_production': 18.70647,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201405',
#    'energy_production': 9.11345,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201404',
#    'energy_production': 19.03014,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201403',
#    'energy_production': 11.35078,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201402',
#    'energy_production': 4.23899,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201401',
#    'energy_production': 7.24,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201312',
#    'energy_production': 9.86624,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201311',
#    'energy_production': 10.10642,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201310',
#    'energy_production': 9.65963,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201309',
#    'energy_production': 15.06117,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201308',
#    'energy_production': 17.44717,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201307',
#    'energy_production': 15.40162,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201306',
#    'energy_production': 18.67837,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201305',
#    'energy_production': 9.86422,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201304',
#    'energy_production': 7.16001,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201303',
#    'energy_production': 7.46205,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201302',
#    'energy_production': 16.50547,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201301',
#    'energy_production': 8.07664,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201212',
#    'energy_production': 6.55997,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201211',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201210',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201209',
#    'energy_production': 4.48528,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201208',
#    'energy_production': 1.90699,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201207',
#    'energy_production': 2.79567,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201206',
#    'energy_production': 1.67562,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201205',
#    'energy_production': 2.16885,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201204',
#    'energy_production': 2.00854,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201203',
#    'energy_production': 2.04053,
#    'fuel_type': 'wind'},
#   {'region': 'California',
#    'date': '201202',
#    'energy_production': 1.44879,
# ...
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201506',
#    'energy_production': 13.09057,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201505',
#    'energy_production': 17.08183,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201504',
#    'energy_production': 19.18777,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201503',
#    'energy_production': 11.07535,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201502',
#    'energy_production': 9.88483,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201501',
#    'energy_production': 4.93735,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201412',
#    'energy_production': 11.537,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201411',
#    'energy_production': 12.90254,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201410',
#    'energy_production': 13.70742,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201409',
#    'energy_production': 9.0683,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201408',
#    'energy_production': 15.70777,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201407',
#    'energy_production': 19.35414,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201406',
#    'energy_production': 18.70647,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201405',
#    'energy_production': 9.11345,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201404',
#    'energy_production': 19.03014,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201403',
#    'energy_production': 11.35078,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201402',
#    'energy_production': 4.23899,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201401',
#    'energy_production': 7.24,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201312',
#    'energy_production': 9.86624,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201311',
#    'energy_production': 10.10642,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201310',
#    'energy_production': 9.65963,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201309',
#    'energy_production': 15.06117,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201308',
#    'energy_production': 17.44717,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201307',
#    'energy_production': 15.40162,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201306',
#    'energy_production': 18.67837,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201305',
#    'energy_production': 9.86422,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201304',
#    'energy_production': 7.16001,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201303',
#    'energy_production': 7.46205,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201302',
#    'energy_production': 16.50547,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201301',
#    'energy_production': 8.07664,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201212',
#    'energy_production': 6.55997,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201211',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201210',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201209',
#    'energy_production': 4.48528,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201208',
#    'energy_production': 1.90699,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201207',
#    'energy_production': 2.79567,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201206',
#    'energy_production': 1.67562,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201205',
#    'energy_production': 2.16885,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201204',
#    'energy_production': 2.00854,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201203',
#    'energy_production': 2.04053,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201202',
#    'energy_production': 1.44879,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201201',
#    'energy_production': None,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201112',
#    'energy_production': 1.62115,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201111',
#    'energy_production': 1.68208,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201110',
#    'energy_production': 1.15438,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201109',
#    'energy_production': 0.7534,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201108',
#    'energy_production': 1.42933,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201107',
#    'energy_production': 1.29988,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201106',
#    'energy_production': 1.09003,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201105',
#    'energy_production': 0.93613,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201104',
#    'energy_production': 0.43814,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201103',
#    'energy_production': 1.56418,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201102',
#    'energy_production': 0.05916,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201101',
#    'energy_production': 0.41813,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201012',
#    'energy_production': 0.36093,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201011',
#    'energy_production': 0.71944,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201010',
#    'energy_production': 1.13217,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201009',
#    'energy_production': 1.17705,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201008',
#    'energy_production': 1.76385,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201007',
#    'energy_production': 1.37293,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201006',
#    'energy_production': 1.25046,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201005',
#    'energy_production': 0.99963,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201004',
#    'energy_production': 1.36203,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201003',
#    'energy_production': 1.36758,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201002',
#    'energy_production': 0.68505,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '201001',
#    'energy_production': 0.41588,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200912',
#    'energy_production': 0.30953,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200911',
#    'energy_production': 1.22224,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200910',
#    'energy_production': 0.5067,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200909',
#    'energy_production': 1.21284,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200908',
#    'energy_production': 1.28276,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200907',
#    'energy_production': 1.32511,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200906',
#    'energy_production': 0.87538,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200905',
#    'energy_production': 0.00283,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200904',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200903',
#    'energy_production': 0.08362,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200902',
#    'energy_production': 0.08875,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200901',
#    'energy_production': 0.04826,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200812',
#    'energy_production': 0.00327,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200811',
#    'energy_production': 0.00467,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200810',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200809',
#    'energy_production': 0.00493,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200808',
#    'energy_production': 0.00839,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200807',
#    'energy_production': 0.00717,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200806',
#    'energy_production': 0.00624,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200805',
#    'energy_production': 0.00591,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200804',
#    'energy_production': 0.00536,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200803',
#    'energy_production': 0.00471,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200802',
#    'energy_production': 0.00334,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200801',
#    'energy_production': 0.00864,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200712',
#    'energy_production': 0.11317,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200711',
#    'energy_production': 0.05208,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200710',
#    'energy_production': 0.12629,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200709',
#    'energy_production': 0.10029,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200708',
#    'energy_production': 0.0955,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200707',
#    'energy_production': 0.12725,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200706',
#    'energy_production': 0.08737,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200705',
#    'energy_production': 0.06506,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200704',
#    'energy_production': 0.08433,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200703',
#    'energy_production': 0.04894,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200702',
#    'energy_production': 0.05536,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200701',
#    'energy_production': 0.05639,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200612',
#    'energy_production': 0.08516,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200611',
#    'energy_production': 0.07921,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200610',
#    'energy_production': 0.07014,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200609',
#    'energy_production': 0.04942,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200608',
#    'energy_production': 0.04047,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200607',
#    'energy_production': 0.04676,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200606',
#    'energy_production': 0.04585,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200605',
#    'energy_production': 0.06834,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200604',
#    'energy_production': 0.07261,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200603',
#    'energy_production': 0.07225,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200602',
#    'energy_production': 0.07075,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200601',
#    'energy_production': 0.08703,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200512',
#    'energy_production': 0.07937,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200511',
#    'energy_production': 0.09749,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200510',
#    'energy_production': 0.07092,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200509',
#    'energy_production': 0.0535,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200508',
#    'energy_production': 0.02536,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200507',
#    'energy_production': 0.02818,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200506',
#    'energy_production': 0.04122,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200505',
#    'energy_production': 0.04858,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200504',
#    'energy_production': 0.04573,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200503',
#    'energy_production': 0.04518,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200502',
#    'energy_production': 0.0304,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200501',
#    'energy_production': 0.02308,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200312',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200311',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200310',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200309',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200308',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200307',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200306',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200305',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200304',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200303',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200302',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200301',
#    'energy_production': 0,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200112',
#    'energy_production': 0.097,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200111',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200110',
#    'energy_production': 0.083,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200109',
#    'energy_production': 0.086,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200108',
#    'energy_production': 0.073,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200107',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200106',
#    'energy_production': 0.07,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200105',
#    'energy_production': 0.069,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200104',
#    'energy_production': 0.071,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200103',
#    'energy_production': 0.081,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200102',
#    'energy_production': 0.074,
#    'fuel_type': 'wind'},
#   {'region': 'Connecticut',
#    'date': '200101',
#    'energy_production': 0.087,
#    'fuel_type': 'wind'}]]

# %%
formatted_alaska_wind_data = np.ravel(formatted_wind_region_series_data)
formatted_alaska_wind_data = [data for data in formatted_alaska_wind_data]
formatted_alaska_wind_data[:5]
# Out:
# [{'region': 'Alaska',
#   'date': '201812',
#   'energy_production': 11.84345,
#   'fuel_type': 'wind'},
#  {'region': 'Alaska',
#   'date': '201811',
#   'energy_production': 11.98104,
#   'fuel_type': 'wind'},
#  {'region': 'Alaska',
#   'date': '201810',
#   'energy_production': 10.25316,
#   'fuel_type': 'wind'},
#  {'region': 'Alaska',
#   'date': '201809',
#   'energy_production': 9.39741,
#   'fuel_type': 'wind'},
#  {'region': 'Alaska',
#   'date': '201808',
#   'energy_production': None,
#   'fuel_type': 'wind'}]

# %%
pd.DataFrame(formatted_alaska_wind_data).tail()
# Out:
#         date  energy_production fuel_type   region
# 9979  200105              0.069      wind  Wyoming
# 9980  200104              0.071      wind  Wyoming
# 9981  200103              0.081      wind  Wyoming
# 9982  200102              0.074      wind  Wyoming
# 9983  200101              0.087      wind  Wyoming
